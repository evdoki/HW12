# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import requests

with open('ф.txt', encoding='utf8') as d:
    ful = d.readlines()
listic = [json.loads(a) for a in ful if 'index' not in a]
s=pd.DataFrame(listic)

# %%
s
# Out:
#                                                 vacancy   company  \
# 0      Начинающий специалист по залоговому кредитованию  Тинькофф
# 1                          Начинающий специалист в банк  Тинькофф
# 2     Менеджер по работе с корпоративными клиентами ...  Тинькофф
# 3               Менеджер по привлечению юридических лиц  Тинькофф
# 4               Менеджер по привлечению юридических лиц  Тинькофф
# ...                                                 ...       ...
# 2695               Агент по доставке продуктов Тинькофф  Тинькофф
# 2696               Агент по доставке продуктов Тинькофф  Тинькофф
# 2697                             Представитель Тинькофф  Тинькофф
# 2698                      Дизайнер мобильных приложений  Тинькофф
# 2699               Агент по доставке продуктов Тинькофф  Тинькофф
#
#      creation_date      region                     income    experience  \
# 0       2019-01-15      Москва             от 55 000 руб.  не требуется
# ...

# %%
m=s[['vacancy','income']][s['income']!='не указан']

# %%
m['vacancy']=m['vacancy'].str.lower()
m=m.drop_duplicates()
m['vacancy'].value_counts()
# Out:
# представитель тинькофф                                      11
# консультант по работе с клиентами                            8
# агент по доставке продуктов тинькофф                         8
# менеджер по работе с клиентами                               7
# менеджер по доставке продуктов банка                         7
#                                                             ..
# рекрутер сектора подбора персонала в регионах                1
# менеджер по привлечению юридических лиц                      1
# менеджер по работе с корпоративными клиентами                1
# кредитный инспектор в отдел проверки надежности клиентов     1
# начинающий специалист                                        1
# Name: vacancy, Length: 173, dtype: int64

# %%
import pandas as pd
import pymorphy2
import ssl

url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/data_stat/yandex-stat-q.csv"

df = pd.read_csv(url)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-dc369566341d> in <module>
#       1 import pandas as pd
# ----> 2 import pymorphy2
#       3 import ssl
#       4
#       5 url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/data_stat/yandex-stat-q.csv"
#
# ModuleNotFoundError: No module named 'pymorphy2'

# %%
mrph = pymorphy2.MorphAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-02ad2fd98c90> in <module>
# ----> 1 morph = pymorphy2.MorphAnalyzer()
#
# NameError: name 'pymorphy2' is not defined
